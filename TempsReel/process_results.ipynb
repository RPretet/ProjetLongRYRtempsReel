# %% [markdown]
# # A simple benchmark to to test sched-ext schedulers on NPB Workloads

# %%
import csv
import pandas as pd
from os import listdir

# %%
# read data
files = ["./result/" + f for f in listdir("./result")]
values = [pd.read_csv(f, sep=",") for f in files]
print(values[1])
# Out:
#     measure    time
# 0         0       0
# 1         1    3670
# 2         2    7338
# 3         3   11023
# 4         4   14658
# ..      ...     ...
# 95       95  254400
# 96       96  256141
# 97       97  257882
# 98       98  259622
# 99       99  261364
#
# [100 rows x 2 columns]

# %%
# create visualisations
import matplotlib.pyplot as plt
result = []
for v in values:
    subtable = dict()
    for measure, time in values :
        print(measure)
    result.append()
